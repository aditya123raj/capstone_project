# %% [markdown]
# # **Project Name: - Global Terrorism Analysis**
# BY :- Aditya raj

# %% [markdown]
# **Project Discription**:
# The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic
# data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained
#  by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland. Explore and analyze the
#   data to discover key findings pertaining to terrorist activities.

# %% [markdown]
# # Project Summary:-
#
#
# *   Getting the Dataset
# *   importing Dataset
# *   importing libraries
# *   Finding null data and clean data
# *   Visualisation of problem statement
# *   Conclusion

# %% [markdown]
# # **Problem statement:**
#
#
# *   Most attacked country
#
# *   Year wise terrorism attacks
#
# *   No. of people killed by each terrorist group
#
# *   Maximum number of kills on each country which exceed 200.
# *   Percentage of kills by terrorist group
#
#
# *   Which area and region has what amount of terrorist activity and how many number of attacks and how many number of attacks are found
#
#
# *   Checking targets for the terrorist
#
#
# *   Gangs involved in continious activity
#
#
# *   10 Countries which are having most number of attacks.

# %% [markdown]
# # Importing nessesory libraries needed for the analysis.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import folium as mp
import os

# %% [markdown]
# Importing datasets from device

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-729b7e95-bad3-4c3e-95d1-3c42b588472f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-729b7e95-bad3-4c3e-95d1-3c42b588472f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('Global Terrorism Data (1).csv',encoding='latin1')
data
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# ...

# %%
# checking top rows of the data.
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
# checking last rows of the data
data.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
# confirming no. of columns and row available!
data.shape
# Out:
# (181691, 135)

# %%
 # checking type of the data
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# checking data types for the vriables
data.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
# Asking the discriptive statistics of the data
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
# checking the corelation between the columns, 
#few observation made like event id is having 90% +ve corelation with iyear.
# showing strong corelation in eventid and iyear similarly as others shown in below.
data.corr()
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.077852 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.175605 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %%
# tells the summary of data
data.summary
# Out:
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
#                                 ...
# 181686    12/31/2017: Assailants opened fire on a Somali...
# 181687    12/31/2017: Assailants launched mortars at the...
# 181688    12/31/2017: Assailants set fire to houses in K...
# 181689    12/31/2017: Assailants threw a grenade at a Fo...
# 181690    12/31/2017: An explosive device was discovered...
# Name: summary, Length: 181691, dtype: object

# %%
 #checking for null values and asking to give sum of null values, there are two variables having null.
data.isnull().sum() #checking for null values and asking to give sum of null values, there are two variables having null.
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# checks specifically rows which are 181691
data.shape[0]
# Out:
# 181691

# %% [markdown]
# Percentage(%) of null in individual columns.

# %%
# checking null in column % wise
null_values=(data.isnull().sum()/data.shape[0])*100
null_values
# Out:
# eventid        0.000000
# iyear          0.000000
# imonth         0.000000
# iday           0.000000
# approxdate    94.914993
#                 ...
# INT_LOG        0.000000
# INT_IDEO       0.000000
# INT_MISC       0.000000
# INT_ANY        0.000000
# related       86.219461
# Length: 135, dtype: float64

# %% [markdown]
# We can see that approxdate 94.914993%, related 86.219461% of null values in these two columns so we also have to check for all columns

# %%
 # storing null values in a variable having more than 10% null values
columns_to_drop =null_values [null_values >10].keys()

# %%
columns_to_drop
# Out:
# Index(['approxdate', 'resolution', 'location', 'summary', 'alternative',
#        'alternative_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3',
#        'attacktype3_txt', 'corp1', 'targtype2', 'targtype2_txt',
#        'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2',
#        'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3',
#        'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt',
#        'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive',
#        'guncertain2', 'guncertain3', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'claimmode2_txt',
#        'claim3', 'claimmode3', 'claimmode3_txt', 'compclaim', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
# ...

# %%
# storing in a variable having not null entirely
after_droped_df = data.drop(columns= columns_to_drop)

# %%
#we observe we still have null values
after_droped_df.isnull().sum()
# Out:
# eventid                 0
# iyear                   0
# imonth                  0
# iday                    0
# extended                0
# country                 0
# country_txt             0
# region                  0
# region_txt              0
# provstate             421
# city                  434
# latitude             4556
# longitude            4557
# specificity             6
# vicinity                0
# crit1                   0
# crit2                   0
# crit3                   0
# doubtterr               1
# multiple                1
# success                 0
# suicide                 0
# attacktype1             0
# attacktype1_txt         0
# targtype1               0
# targtype1_txt           0
# targsubtype1        10373
# targsubtype1_txt    10373
# target1               636
# natlty1              1559
# natlty1_txt          1559
# gname                   0
# guncertain1           380
# individual              0
# weaptype1               0
# ...

# %%
#chwecking row and columns left after the removing nuyll values
after_droped_df.shape
# Out:
# (181691, 45)

# %% [markdown]
# Let's perform plotting/visualization part for null to check whther all null values are removed or some are left.

# %%
#using heatmap for null values to check.
sns.heatmap(after_droped_df.isnull())

# %% [markdown]
# As we can see  there are still many null values available which still need treatment.

# %%
after_droped_df=after_droped_df.dropna()

# %%
# checking in boolean fashion if true= yes null, false= not not there
after_droped_df.isna()
# Out:
#         eventid  iyear  imonth   iday  extended  country  country_txt  region  \
# 1         False  False   False  False     False    False        False   False
# 2         False  False   False  False     False    False        False   False
# 5         False  False   False  False     False    False        False   False
# 6         False  False   False  False     False    False        False   False
# 7         False  False   False  False     False    False        False   False
# ...         ...    ...     ...    ...       ...      ...          ...     ...
# 181685    False  False   False  False     False    False        False   False
# 181686    False  False   False  False     False    False        False   False
# 181687    False  False   False  False     False    False        False   False
# 181688    False  False   False  False     False    False        False   False
# 181689    False  False   False  False     False    False        False   False
#
# ...

# %% [markdown]
# Lets confirm null values are not there now

# %%
after_droped_df.isna().sum()# confirming null if removed
# Out:
# eventid             0
# iyear               0
# imonth              0
# iday                0
# extended            0
# country             0
# country_txt         0
# region              0
# region_txt          0
# provstate           0
# city                0
# latitude            0
# longitude           0
# specificity         0
# vicinity            0
# crit1               0
# crit2               0
# crit3               0
# doubtterr           0
# multiple            0
# success             0
# suicide             0
# attacktype1         0
# attacktype1_txt     0
# targtype1           0
# targtype1_txt       0
# targsubtype1        0
# targsubtype1_txt    0
# target1             0
# natlty1             0
# natlty1_txt         0
# gname               0
# guncertain1         0
# individual          0
# weaptype1           0
# weaptype1_txt       0
# nkill               0
# nwound              0
# property            0
# ishostkid           0
# dbsource            0
# ...

# %% [markdown]
# Let's plotting heatmap again to see  null values are there or not

# %%
sns.heatmap(after_droped_df.isnull())

# %% [markdown]
# From above fig we can say that yes null has been completely removed!

# %% [markdown]
# # Let select column which can gives us some insight and rejects some columns which are useless.

# %%
# checking total number of columns I am having, turned out to be 45.
after_droped_df.columns.value_counts().sum()
# Out:
# 45

# %%
# Let's see what are those
after_droped_df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'extended', 'country',
#        'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude',
#        'longitude', 'specificity', 'vicinity', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'multiple', 'success', 'suicide', 'attacktype1',
#        'attacktype1_txt', 'targtype1', 'targtype1_txt', 'targsubtype1',
#        'targsubtype1_txt', 'target1', 'natlty1', 'natlty1_txt', 'gname',
#        'guncertain1', 'individual', 'weaptype1', 'weaptype1_txt', 'nkill',
#        'nwound', 'property', 'ishostkid', 'dbsource', 'INT_LOG', 'INT_IDEO',
#        'INT_MISC', 'INT_ANY'],
#       dtype='object')

# %%
# I identified and selected columns which required no change,
#and we dont need those either they containing demographic imformaton or they are giving not putting much contaxt to our analysis
# So let's remove them
# droping columns I will purt inside list because there are more columns to remove as well can see above
after_droped_2=after_droped_df.drop(columns=['extended', 'country','region','specificity', 'vicinity', 'crit1', 'crit2', 'crit3',
       'doubtterr', 'multiple','weaptype1','attacktype1','targtype1','targsubtype1','natlty1', 'natlty1_txt',
       'guncertain1', 'individual', 
        'weaptype1','property', 'ishostkid', 'dbsource','INT_LOG', 
        'INT_IDEO', 'INT_MISC', 'INT_ANY'])

# %%
after_droped_2.columns # confirmed that columns are removed
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'country_txt', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'success', 'suicide',
#        'attacktype1_txt', 'targtype1_txt', 'targsubtype1_txt', 'target1',
#        'gname', 'weaptype1_txt', 'nkill', 'nwound'],
#       dtype='object')

# %%
after_droped_2.shape# after droping cheking the total no. of columns and rows available in df turned out to be 149355, 20
# Out:
# (149355, 20)

# %% [markdown]
# # After observing above columns they look not much sensible to me, now want to make them bit more better by renaming them.
#
# # There are many columns o rename so I am going to put them in the form of dictionary simply.

# %%
after_droped_2=after_droped_2.rename(columns={
    'eventid':'event_id',
    'iyear':'year',
    'imonth':'month',
    'iday':'day',
    'country_txt':'country',
    'region_txt':'region',
       'provstate':'state',
       'attacktype1_txt':'attack_type',
    'targtype1_txt':'targ_type',
    'targsubtype1_txt':'targsub_type',
    'target1':'main_target',
       'gname':'gang_name',
    'weaptype1_txt':'weapon_type',
    'nkill':'number_of_kill',
    'nwound':'number_of_wound'
    
}) # Renaming in the form of dictionary

# %%
after_droped_2.columns # Let's see and confirm if it worked or not
# Out:
# Index(['event_id', 'year', 'month', 'day', 'country', 'region', 'state',
#        'city', 'latitude', 'longitude', 'success', 'suicide', 'attack_type',
#        'targ_type', 'targsub_type', 'main_target', 'gang_name', 'weapon_type',
#        'number_of_kill', 'number_of_wound'],
#       dtype='object')

# %% [markdown]
# Renaming successful!

# %% [markdown]
# # most attacks in : Country, City,Region, Year, Group, Attack Type

# %%
print('Country with most attacks: ',after_droped_2['country'].value_counts().idxmax())
Country_with_most_attacks=after_droped_2['country'].value_counts().idxmax()
after_droped_2[after_droped_2['country']==Country_with_most_attacks]
print('City with most attacks: ',after_droped_2['city'].value_counts().idxmax())
City_with_most_attacks=after_droped_2['city'].value_counts().idxmax()

print("Region with the most attacks:",after_droped_2['region'].value_counts().idxmax())
Region_with_the_most_attacks=after_droped_2['region'].value_counts().idxmax()

print("Year with the most attacks:",after_droped_2['year'].value_counts().idxmax())
Year_with_the_most_attacks=after_droped_2['year'].value_counts().idxmax()
    
print("Month with the most attacks:",after_droped_2['month'].value_counts().idxmax())
Month_with_the_most_attacks=after_droped_2['month'].value_counts().idxmax()

print("Group with the most attacks:",after_droped_2['gang_name'].value_counts().index[1])
Group_with_the_most_attacks=after_droped_2['gang_name'].value_counts().index[1]

print("Most Attack Types:",after_droped_2['attack_type'].value_counts().idxmax())
Most_Attack_Types=after_droped_2['attack_type'].value_counts().idxmax()
# Out:
# Country with most attacks:  Iraq
# City with most attacks:  Baghdad
# Region with the most attacks: Middle East & North Africa
# Year with the most attacks: 2014
# Month with the most attacks: 5
# Group with the most attacks: Taliban
# Most Attack Types: Bombing/Explosion

# %% [markdown]
# # Let's plot in map to see most attacked country

# %%
Country_with_most_attacks_latitude=after_droped_2[after_droped_2['country']==Country_with_most_attacks].iloc[0:9]
ma=mp.Map(location=[36.354145,43.143570])
for i in Country_with_most_attacks_latitude.itertuples():
    mp.Marker(location=[i.latitude,i.longitude],popup=i.city
).add_to(ma)
ma # running for loop to see for all the most attacked countries.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # **Map shows 4 location as per coordinates with most attacked country.**
#
#
# *  Basra
#
# *  Mosul
# *  Kirkuk
#
#
# *  Baghdad

# %% [markdown]
# # Let's look year wise terrorism attacks

# %%
x_year = after_droped_2['year'].unique() # plotting using barplot year and number of killing happend.
y_year = after_droped_2['year'].value_counts().sort_index()
plt.figure(figsize=(12,8))
plt.bar(x_year, y_year)
plt.title('NUMBER OF KILL PER YEAR')
plt.xlabel('YEAR')
plt.ylabel('COUNTS OF KILLING')
plt.show()

# %% [markdown]
# According to above observation,it can be concluded that number of kills increased rapidly after 2010 and where 2014 being the most deadly year having maximum number of killing.*

# %% [markdown]
# # Terrorist Group and Number of killing

# %%
#grouping using groupby
group_killed= after_droped_2[['gang_name','number_of_kill']].groupby(['gang_name'],axis=0).sum().sort_values('number_of_kill', ascending=False).head(20)
group_killed.reset_index()
# Out:
#                                            gang_name  number_of_kill
# 0                                            Unknown         95399.0
# 1        Islamic State of Iraq and the Levant (ISIL)         27174.0
# 2                                            Taliban         25785.0
# 3                                         Boko Haram         10732.0
# 4            Liberation Tigers of Tamil Eelam (LTTE)          9393.0
# 5                                  Shining Path (SL)          9315.0
# 6                                         Al-Shabaab          6836.0
# 7   Farabundo Marti National Liberation Front (FMLN)          6801.0
# 8                    Tehrik-i-Taliban Pakistan (TTP)          5580.0
# 9      Revolutionary Armed Forces of Colombia (FARC)          4380.0
# 10                    Kurdistan Workers' Party (PKK)          4093.0
# 11                                  Al-Qaida in Iraq          3984.0
# 12                 Nicaraguan Democratic Force (FDN)          3883.0
# ...

# %% [markdown]
# Number of poeple killed by each terrorist group

# %%
plt.subplots(figsize=(10,4))
sns.barplot(group_killed.index, group_killed.number_of_kill.values,palette="crest")
plt.title('Number of People Killed by each terrorist group')
plt.xlabel('Terrorist Groups')
plt.ylabel('Number of people killed')
plt.xticks(rotation= 75)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# *  Above figure show that there have been most killing by Unknown group.
#
# *  2nd was Islamic State of Iraq and Levant.
# *  Least killing made by Communist Party of India and Mozambique National Resistance Movement.

# %%
# checking maximum lives lost
after_droped_2[after_droped_2['number_of_kill']==after_droped_2.number_of_kill.max()]
# Out:
#            event_id  year  month  day        country         region     state  \
# 73126  200109110004  2001      9   11  United States  North America  New York
#
#                 city   latitude  longitude  success  suicide attack_type  \
# 73126  New York City  40.697132 -73.931351        1        1   Hijacking
#
#                          targ_type                  targsub_type  \
# 73126  Private Citizens & Property  Unnamed Civilian/Unspecified
#
#                                              main_target gang_name  \
# 73126  Passengers and crew members on American Airlin...  Al-Qaida
#
#                                              weapon_type  number_of_kill  \
# 73126  Vehicle (not to include vehicle-borne explosiv...          1384.0
#
#        number_of_wound
# 73126           8190.0

# %% [markdown]
# * Above data tells that we have in the year 2001 most killing with 1384 lives.
#
# *  Wounded were 8190 lives.
# *
# Al- Qaida terrorist group involved and it was in Hijacking of Airlines.

# %% [markdown]
# Below is showing the Maximum Number of killing in each country

# %%
grouping_country=after_droped_2.groupby('country')# grouping the country to see the maximum number of killing
max_number_of_kill_in_each_country=grouping_country.max('number_of_kill')
max_number_of_kill_in_each_country
# Out:
#                  event_id  year  month  day   latitude  longitude  success  \
# country
# Afghanistan  201712310020  2017     12   31  37.769393  71.584167        1
# Albania      201710110028  2017     12   29  42.399981  20.421944        1
# Algeria      201709220009  2017     12   31  37.068190   9.556767        1
# Angola       201708250057  2017     12   31  -4.446342  23.016835        1
# Argentina    201708020032  2017     12   31 -23.276090 -55.900812        1
# ...                   ...   ...    ...  ...        ...        ...      ...
# Yemen        201712290016  2017     12   31  17.489364  50.581538        1
# Yugoslavia   200206130002  2002     12   31  46.100278  22.143022        1
# Zaire        199705120008  1997     12   31   1.010278  29.593583        1
# Zambia       201707090040  2017     12   31 -12.166857  32.902500        1
# Zimbabwe     201707180043  2017     12   31 -16.646518  32.800000        1
#
#              suicide  number_of_kill  number_of_wound
# ...

# %%
max_number_of_kill_in_each_country=max_number_of_kill_in_each_country[max_number_of_kill_in_each_country['number_of_kill']>300]
max_number_of_kill_in_each_country=max_number_of_kill_in_each_country.reset_index()
max_number_of_kill_in_each_country # checking the number of killing exceeding 300 in each coutry wise
# Out:
#           country      event_id  year  month  day   latitude   longitude  \
# 0         Burundi  201712040036  2017     12   31  -2.525794   30.770913
# 1          Canada  201709300013  2017     12   31  55.754211  -64.778231
# 2           Egypt  201712290003  2017     12   31  31.441411   34.899447
# 3            Iran  201707150027  2017     12   31  39.391389   62.348337
# 4            Iraq  201712310012  2017     12   31  37.230226   70.064041
# 5      Mozambique  201712170030  2017     12   31 -10.596982   40.672784
# 6           Nepal  201712220016  2017     12   31  29.916806   88.155974
# 7          Russia  201712280028  2017     12   31  74.633553  158.383333
# 8          Rwanda  201706200037  2017     12   31  -1.448369   30.775917
# 9         Somalia  201712310022  2017     12   31  11.472014   51.077309
# 10  United States  201712220023  2017     12   31  64.837778  105.270546
#
#     success  suicide  number_of_kill  number_of_wound
# ...

# %%
plt.figure(figsize=(20,15)) # CHEKING USING BAR PLOT AND FOR LOOP
#fINDING MAMIMUM NUMBER OF KILLS IN EACH COUNTRY WHICH EXCEEDED 200.
plt.xlabel('COUNTRY')
plt.ylabel('NUMBER OF KILL')
plt.title('Max_Number_Of_Kill_In_Each_Country Which Is Greater Then 200')
plt.bar(max_number_of_kill_in_each_country.country,max_number_of_kill_in_each_country.number_of_kill,label='Number of kill')
plt.legend()
for i in range(len(max_number_of_kill_in_each_country['country'])):
        plt.text(max_number_of_kill_in_each_country['country'][i],max_number_of_kill_in_each_country['number_of_kill'][i],max_number_of_kill_in_each_country['number_of_kill'][i],fontsize=25)

# %% [markdown]
# # Since Al-Qaida was accuntable for most number of kills in 2001, let understand more about Al-Qaida

# %%
group_gname=after_droped_2.groupby('gang_name')
Al_Qaida=group_gname.get_group('Al-Qaida')
Al_Qaida
# Out:
#             event_id  year  month  day   country                      region  \
# 54691   199212290002  1992     12   29     Yemen  Middle East & North Africa
# 54692   199212290003  1992     12   29     Yemen  Middle East & North Africa
# 68071   199808070002  1998      8    7     Kenya          Sub-Saharan Africa
# 68072   199808070003  1998      8    7  Tanzania          Sub-Saharan Africa
# 69876   200001030010  2000      1    3     Yemen  Middle East & North Africa
# ...              ...   ...    ...  ...       ...                         ...
# 85923   200803110011  2008      3   11  Pakistan                  South Asia
# 85944   200803150001  2008      3   15  Pakistan                  South Asia
# 87834   200807090016  2008      7    9    Turkey  Middle East & North Africa
# 95008   201001190011  2010      1    0  Pakistan                  South Asia
# 102708  201108130011  2011      8   13  Pakistan                  South Asia
#
# ...

# %%
Al_Qaida[Al_Qaida['number_of_kill']>20] # checking  nuo. of killing more than 20
# Out:
#            event_id  year  month  day         country  \
# 68071  199808070002  1998      8    7           Kenya
# 73126  200109110004  2001      9   11   United States
# 73127  200109110005  2001      9   11   United States
# 73128  200109110006  2001      9   11   United States
# 73129  200109110007  2001      9   11   United States
# 73959  200204110003  2002      4   11         Tunisia
# 76324  200403110001  2004      3   11           Spain
# 76326  200403110003  2004      3   11           Spain
# 76330  200403110007  2004      3   11           Spain
# 78219  200506010001  2005      6    1     Afghanistan
# 78432  200507070002  2005      7    7  United Kingdom
# 83837  200707140001  2007      7   14        Pakistan
# 85923  200803110011  2008      3   11        Pakistan
#
#                            region                                state  \
# 68071          Sub-Saharan Africa                              Nairobi
# ...

# %% [markdown]
# **Few Observation to made:**
#
#
#
#
#
# *  Al-qaida group have done most killings.
# *  Weapon used for killing is only two: 1)Explosives and 2)vehicle-borne explosive.
#
# * Year 2001 more than 1 attack by Al- Qaida.

# %%
#to check which region is affected by terrorism in each year using ipywidget and importing interact
from ipywidgets import interact, interact_manual
@interact

def attack_year(year=list(after_droped_2["year"].unique())):
    a=after_droped_2[after_droped_2["year"]==year]
    return sns.countplot(y=a["region"], palette="viridis")
# Out:
# interactive(children=(Dropdown(description='year', options=(1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 19…

# %%
sns.heatmap(after_droped_2[['year','number_of_kill','suicide']].corr(), annot=True, cmap = 'Reds') # cheking corelation

# %%
after_droped_2.columns.value_counts().sum() # checked total number of columns are 20 left
# Out:
# 20

# %%
after_droped_2.columns# checked which are those
# Out:
# Index(['event_id', 'year', 'month', 'day', 'country', 'region', 'state',
#        'city', 'latitude', 'longitude', 'success', 'suicide', 'attack_type',
#        'targ_type', 'targsub_type', 'main_target', 'gang_name', 'weapon_type',
#        'number_of_kill', 'number_of_wound'],
#       dtype='object')

# %%
data1=after_droped_2.gang_name.value_counts(normalize=True,ascending=False)#p%age of kills by terrorist group.
data1.head(20).plot.pie(autopct="%.1f%%",figsize=(20,15))
plt.show()

# %%
pd.crosstab(after_droped_2.year,after_droped_2.region).plot(kind='area',figsize=(20,15))
# which year and region has what amount of terrorist activity and how many number of attacks are found.
plt.title('Terrorist Activities')
plt.ylabel('Number of Attacks')
plt.show()

# %%
after_droped_2.targ_type.value_counts(normalize=True).plot(kind='barh',color='Red',figsize=(15,10))
plt.show() # CHECKING WHICH ATTACKERS ARE USING AS TARGET FOR THE ATTACKS

# %%
plt.figure(figsize=(15, 10))
sns.distplot(after_droped_2['year'], color='blue', bins=100, hist_kws={'alpha': 0.8});
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plotting using wordcloud and scipy
from wordcloud import WordCloud
from scipy import signal
cities = after_droped_2.state.dropna(False)
plt.subplots(figsize=(10,10))
wordcloud = WordCloud(background_color = 'white',
                     width = 800,
                     height = 500).generate(' '.join(cities))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()
# Out:
# <ipython-input-57-291859199114>:4: FutureWarning: In a future version of pandas all arguments of Series.dropna will be keyword-only
#   cities = after_droped_2.state.dropna(False)

# %% [markdown]
# # Gangs involved in continuous activity.

# %%
max_killevery_gname=[]
year=[]
g_name=[]
for i in after_droped_2:
  if i=='year':
    for j in range(2004,2018):
      year.append(j)
      attack=after_droped_2[after_droped_2['year']==j]
      max_killevery_gname.append(attack.gang_name.value_counts()[1])
      g_name.append(attack.gang_name.value_counts()[1:2].keys())
most_kill = pd.DataFrame({'year' : year,
                                'gname' : g_name,
                                'Number of Attacks' : max_killevery_gname })
most_kill['gname']=most_kill['gname'].apply(lambda x: x[0] )
plt.figure(figsize=(15,10))
plt.xlabel('Year')
plt.ylabel('Number of Attack')
plt.title('Year wise most active gang')
plt.plot(most_kill['year'],most_kill['Number of Attacks'])
for i in range(len(most_kill['year'])):
        plt.text(most_kill['year'][i],most_kill['Number of Attacks'][i],most_kill['gname'][i][0:12],rotation=70,fontsize=15)

# %% [markdown]
# **From this plot we can conclude few points**
#
#       Most active gangs are Taliban,CPI-Maoist,ISIL
# *   Let's explore in these gangs what type of weapon they use.

# %%
g_name=['Taliban','Communist Party of India - Maoist (CPI-Maoist)','Islamic State of Iraq and the Levant (ISIL)']
for i in g_name:
  print(i,':: '+after_droped_2[after_droped_2['gang_name']==i]['attack_type'].value_counts().idxmax())
# Out:
# Taliban :: Bombing/Explosion
# Communist Party of India - Maoist (CPI-Maoist) :: Armed Assault
# Islamic State of Iraq and the Levant (ISIL) :: Bombing/Explosion

# %% [markdown]
# These gangs are using mostly Bombing/Explosion and Armed Assault.

# %% [markdown]
# # MOST ATTCKED COUNTRY

# %%
most_number_of_attack=pd.DataFrame(after_droped_2['country'].value_counts())# checkingvalue count of country in data
most_number_of_attack=most_number_of_attack.reset_index()# performing column wise operation
most_number_of_attack=most_number_of_attack.rename(columns={'index':'country','country':'number_of_kill'}) # columns renamed

# %%
MOST_ATTCKED_COUNTRY=most_number_of_attack[most_number_of_attack['number_of_kill']>3000]
MOST_ATTCKED_COUNTRY # number of kills greater than 3000 fitering for 11 country
# Out:
#            country  number_of_kill
# 0             Iraq           21510
# 1         Pakistan           12756
# 2      Afghanistan           10871
# 3            India           10491
# 4         Colombia            6865
# 5      Philippines            5843
# 6             Peru            4916
# 7           Turkey            3767
# 8      El Salvador            3369
# 9         Thailand            3346
# 10  United Kingdom            3212

# %% [markdown]
# We can conclude that there are 11 countries which are having most numbers of attacks.

# %%
plt.figure(figsize=(10,5))
plt.barh(MOST_ATTCKED_COUNTRY.country,MOST_ATTCKED_COUNTRY.number_of_kill) # visualizing the smae
# Out:
# <BarContainer object of 11 artists>

# %%
Taliban=after_droped_2[after_droped_2['gang_name']=='Taliban']
Taliban_number_attack=Taliban['country'].count()
Taliban_number_kill=Taliban['number_of_kill'].sum()
CPI=after_droped_2[after_droped_2['gang_name']=='Communist Party of India - Maoist (CPI-Maoist)']
CPI_number_attack=CPI['country'].count()
CPI_number_kill=CPI['number_of_kill'].sum()
ISIL=after_droped_2[after_droped_2['gang_name']=='Islamic State of Iraq and the Levant (ISIL)']
ISIL_number_attack=ISIL['country'].count()
ISIL_number_kill=ISIL['number_of_kill'].sum()
name_of_gang=['Taliban','CPI','ISIL']
plt.figure(figsize=(15,10))
x_nu_attack=[Taliban_number_attack,CPI_number_attack,ISIL_number_attack]
y_nu_kill=[Taliban_number_kill,CPI_number_kill,ISIL_number_kill]
plt.plot(x_nu_attack,y_nu_kill,'Dr')
plt.grid()
plt.title('KILL VS ATTACKS')
plt.xlabel('NUMBER OF ATTACKS')
plt.ylabel('NUMBER OF KILL')
for i in range(len(x_nu_attack)):
        plt.text(x_nu_attack[i],y_nu_kill[i],name_of_gang[i],fontsize=10)
# so we can write here out three active gang from last 20 year ISIL is the most attacks and killed org.

# %% [markdown]
# *  We can conclude that most attacks and most killings are performed by ISIL followed by Taiban.

# %% [markdown]
# # Conclusion

# %% [markdown]
# **Most attacks**
#
#
# *   Country with most attacks: Iraq
# *   City with most attacks: Baghdad
# *   Region with the most attacks: Middle East & North Africa
# *   Year with the most attacks: 2014
# *   Year with the most attacks: 2014
# *   Group with the most attacks: Taliban
# *   Most Attack Types: Bombing/Explosion
#
# **Map shows 4 location as per coordinates with most attacked country.**
#
# *   Basra
# *   Mosul
# *   Kirkuk
# *   Baghdad
#
# **After ploting attacks with years.**
#
# *   Number of kills increased rapidly after 2010 and where 2014 being the most deadly year having maximum number of killing.
#
# **These three groups has been more contagious.**
# *   Unknown 95399.0(number of kills).
# *   Islamic State of Iraq and the Levant (ISIL) 27174.0(number of kills).
# *   Taliban 25785.0(number of kills).
#
#
#
#
#
#
# **Most killing in year.**
#
# *   Analysis tells that we have in the year 2001 most killing with 1340 lives.
# *   Wounded were 8190 lives.
# *   Al- Qaeda terrorist group involved and it was in Hijacking of Airlines.
#
# **Few Observation about Al-Qaeda.**
#
# *   Al-qaida group have done most killings.
#
# *   Weapon used for killing is only two: 1)Explosives and 2)vehicle-borne explosive
# *   Year 2001 more than 1 attack by Al- Qaeda.
#
#
# *   Seems like USA and Al-Qaida were in war for some issue
#
# **Top active Terrorist group.**
#
# *   Most active gangs are Taliban,CPI-Maoist,ISIL.
#
# *   These gangs are using mostly Bombing/Explosion and Armed Assault.
# *   We can conclude that most attacks and most killings are performed by ISIL followed by Taiban.

# %%
after_droped_2.to_excel('EDA.xlsx')
